# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Brian Kwon**
# Data Scientist

# %% [markdown]
# *I am interested in Data Science because I want to be able to use data to help solve real and practical problems*

# %% [markdown]
# ### The code in Cell 5 will add the numbers 1 and 1 to add up to 2

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# - Bulleted List 1
# - Bulleted List 2
#
# 1. Numbered List 1
# 2. Numbered List 2
#
# ![Image](image.jpg)
